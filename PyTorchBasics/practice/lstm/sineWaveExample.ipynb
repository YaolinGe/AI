# %%
import torch 
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import matplotlib.pyplot as plt
import random
import time
import os

# %%
def truth_func(x): 
    return np.sin(x) + np.sin(3*x) + np.sin(5*x)
    # return np.sin(x)

X_train = np.arange(0, 50, .5)
Y_train = truth_func(X_train)

X_test = np.arange(50, 100, .5)
Y_test = truth_func(X_test)

plt.figure(figsize=(15, 4))
plt.plot(X_train, Y_train, label="Train data")
plt.plot(X_test, Y_test, label="Test data")
plt.legend(loc="lower left")
plt.show()

def create_dataset(data, look_back:int=1): 
    X, Y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:(i + look_back)])
        Y.append(data[i + look_back])
    return torch.tensor(X, dtype=torch.float32).view(-1, look_back, 1), torch.tensor(Y, dtype=torch.float32).view(-1, 1)

look_back = 20

trainX, trainY = create_dataset(Y_train, look_back)
testX, testY = create_dataset(Y_test, look_back)

train_loader = DataLoader(TensorDataset(trainX, trainY), batch_size=32, shuffle=True)
test_loader = DataLoader(TensorDataset(testX, testY), batch_size=32, shuffle=True)

print(trainX.shape, trainY.shape, testX.shape, testY.shape)

for x, y in train_loader:
    print(x.shape, y.shape)
    break

# for i in range(trainX.shape[0]): 
#     plt.figure(figsize=(20, 4))
#     plt.plot(X_train, Y_train)
#     plt.plot(X_train[i:i+20], trainX[i].view(-1).numpy())
#     plt.plot(X_train[i+20], trainY[i].view(-1).numpy(), 'ro')
#     plt.show()
#     if i > 10: break
# Out:
# torch.Size([80, 20, 1]) torch.Size([80, 1]) torch.Size([80, 20, 1]) torch.Size([80, 1])
# torch.Size([32, 20, 1]) torch.Size([32, 1])

# %%
trainX.shape
# Out:
# torch.Size([80, 20, 1])

# %%
class LSTMModel(nn.Module): 
    def __init__(self): 
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=100, num_layers=1, batch_first=True)
        self.fc = nn.Linear(100, 1)
    
    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1])
        return x

# %%
a = nn.LSTM(input_size=1, hidden_size=100, num_layers=1, batch_first=True)
b = nn.Linear(100, 1)

input = torch.randn(32, 10, 1)
output1, _ = a(input)
output2 = b(output1[:, -1])
output3 = b(output1)
print(output1.shape, output2.shape, output3.shape)
# Out:
# torch.Size([32, 10, 100]) torch.Size([32, 1]) torch.Size([32, 10, 1])

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

lstm = LSTMModel().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(lstm.parameters(), lr=0.001)

# %%
# Out:
# (190, 190)

# %%
n_epochs = 200
train_loss = []
test_loss = []

for epoch in range(n_epochs):
    lstm.train()
    running_loss = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        output = lstm(x)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_loss.append(running_loss / len(train_loader))

    lstm.eval()
    running_loss = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            output = lstm(x)
            loss = criterion(output, y)
            running_loss += loss.item()
        test_loss.append(running_loss / len(test_loader))

    print(f"Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss[-1]:.4f} - Test Loss: {test_loss[-1]:.4f}")

plt.figure(figsize=(15, 4))
plt.plot(train_loss, label="Train loss")
plt.plot(test_loss, label="Test loss")
plt.legend()
plt.show()
# Out:
# Epoch 1
# Epoch 166/200 - Train Loss: 0.0014 - Test Loss: 0.0014
# Epoch 167/200 - Train Loss: 0.0011 - Test Loss: 0.0016
# Epoch 168/200 - Train Loss: 0.0014 - Test Loss: 0.0013
# Epoch 169/200 - Train Loss: 0.0012 - Test Loss: 0.0013
# Epoch 170/200 - Train Loss: 0.0011 - Test Loss: 0.0017
# Epoch 171/200 - Train Loss: 0.0016 - Test Loss: 0.0031
# Epoch 172/200 - Train Loss: 0.0021 - Test Loss: 0.0029
# Epoch 173/200 - Train Loss: 0.0019 - Test Loss: 0.0040
# Epoch 174/200 - Train Loss: 0.0030 - Test Loss: 0.0024
# Epoch 175/200 - Train Loss: 0.0017 - Test Loss: 0.0023
# Epoch 176/200 - Train Loss: 0.0020 - Test Loss: 0.0014
# Epoch 177/200 - Train Loss: 0.0021 - Test Loss: 0.0012
# Epoch 178/200 - Train Loss: 0.0017 - Test Loss: 0.0019
# Epoch 179/200 - Train Loss: 0.0018 - Test Loss: 0.0017
# Epoch 180/200 - Train Loss: 0.0020 - Test Loss: 0.0018
# Epoch 181/200 - Train Loss: 0.0016 - Test Loss: 0.0014
# Epoch 182/200 - Train Loss: 0.0016 - Test Loss: 0.0017
# Epoch 183/200 - Train Loss: 0.0013 - Test Loss: 0.0027
# Epoch 184/200 - Train Loss: 0.0018 - Test Loss: 0.0021
# Epoch 185/200 - Train Loss: 0.0018 - Test Loss: 0.0023
# Epoch 186/200 - Train Loss: 0.0020 - Test Loss: 0.0028
# Epoch 187/200 - Train Loss: 0.0020 - Test Loss: 0.0025
# Epoch 188/200 - Train Loss: 0.0027 - Test Loss: 0.0013
# Epoch 189/200 - Train Loss: 0.0019 - Test Loss: 0.0012
# Epoch 190/200 - Train Loss: 0.0031 - Test Loss: 0.0038
# Epoch 191/200 - Train Loss: 0.0053 - Test Loss: 0.0096
# Epoch 192/200 - Train Loss: 0.0063 - Test Loss: 0.0137
# Epoch 193/200 - Train Loss: 0.0105 - Test Loss: 0.0167
# Epoch 194/200 - Train Loss: 0.0129 - Test Loss: 0.0261
# Epoch 195/200 - Train Loss: 0.0194 - Test Loss: 0.0200
# Epoch 196/200 - Train Loss: 0.0095 - Test Loss: 0.0238
# Epoch 197/200 - Train Loss: 0.0154 - Test Loss: 0.0304
# Epoch 198/200 - Train Loss: 0.0179 - Test Loss: 0.0149
# Epoch 199/200 - Train Loss: 0.0095 - Test Loss: 0.0066
# Epoch 200/200 - Train Loss: 0.0086 - Test Loss: 0.0040

# %%
# Out:
# (80, 1)

# %%
predY = lstm(testX.to(device)).cpu().detach().numpy()

plt.figure(figsize=(15, 4))
plt.plot(X_train, Y_train, label="Train data")
plt.plot(X_test, Y_test, label="Test data")
plt.plot(X_test[20:], predY, "r-.x", label="Predicted data")
plt.legend(loc="lower left")
plt.show()

plt.figure(figsize=(15, 4))
error = np.abs(Y_test[20:] - predY.flatten())
plt.plot(X_test[20:], error)
plt.title("Total error: %.4f" % np.sum(error))
plt.show()

# %%
look_back = 20
look_forward = 50

class LSTMModelLong(nn.Module): 
    def __init__(self, *args, **kwargs) -> None:
        super().__init__(*args, **kwargs)
        self.lstm = nn.LSTM(input_size=1, hidden_size=100, num_layers=2, batch_first=True)
        self.fc = nn.Linear(100, look_forward)
    
    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.fc(x[:, -1])
        return x

lstm_long = LSTMModelLong().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(lstm_long.parameters(), lr=0.001)

def create_dataset_long(data, look_back:int=1, look_forward:int=1): 
    X, Y = [], []
    for i in range(len(data) - look_back - look_forward):
        X.append(data[i:(i + look_back)])
        Y.append(data[(i + look_back):(i + look_back + look_forward)])
    return torch.tensor(X, dtype=torch.float32).view(-1, look_back, 1), torch.tensor(Y, dtype=torch.float32).view(-1, look_forward)

trainX, trainY = create_dataset_long(Y_train, look_back, look_forward)
testX, testY = create_dataset_long(Y_test, look_back, look_forward)

train_loader = DataLoader(TensorDataset(trainX, trainY), batch_size=32, shuffle=True)
test_loader = DataLoader(TensorDataset(testX, testY), batch_size=32, shuffle=True)

for i in range(3): 
    plt.figure(figsize=(20, 4))
    plt.plot(X_train, Y_train)
    plt.plot(X_train[i:i+look_back], trainX[i].view(-1).numpy(), "rx")
    plt.plot(X_train[i+look_back:i+look_forward+look_back], trainY[i].view(-1).numpy(), "yo")
    plt.show()

# %%
print(trainX.shape, trainY.shape, testX.shape, testY.shape)
# Out:
# torch.Size([180, 10, 1]) torch.Size([180, 10]) torch.Size([180, 10, 1]) torch.Size([180, 10])

# %%
input = torch.randn(32, 10, 1)
a = nn.LSTM(input_size=1, hidden_size=100, num_layers=2, batch_first=True)
b = nn.Linear(100, look_forward)
output1, _ = a(input)
output2 = b(output1)
output3 = b(output1[:, -1])
print(input.shape, output1.shape, output2.shape, output3.shape)
# Out:
# torch.Size([32, 10, 1]) torch.Size([32, 10, 100]) torch.Size([32, 10, 10]) torch.Size([32, 10])

# %%
n_epochs = 200
train_loss = []
test_loss = []

for epoch in range(n_epochs):
    lstm_long.train()
    running_loss = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        output = lstm_long(x)
        loss = criterion(output, y)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    train_loss.append(running_loss / len(train_loader))

    lstm_long.eval()
    running_loss = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            output = lstm_long(x)
            loss = criterion(output, y)
            running_loss += loss.item()
        test_loss.append(running_loss / len(test_loader))

    print(f"Epoch {epoch+1}/{n_epochs} - Train Loss: {train_loss[-1]:.4f} - Test Loss: {test_loss[-1]:.4f}")

plt.plot(train_loss, label="Train loss")
plt.plot(test_loss, label="Test loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/200 - Train Loss: 0.5018 - Test Loss: 0.5005
# Epoch 2/200 - Train Loss: 0.4999 - Test Loss: 0.4987
# Epoch 3/200 - Train Loss: 0.4981 - Test Loss: 0.4969
# Epoch 4/200 - Train Loss: 0.4963 - Test Loss: 0.4950
# Epoch 5/200 - Train Loss: 0.4945 - Test Loss: 0.4932
# Epoch 6/200 - Train Loss: 0.4927 - Test Loss: 0.4912
# Epoch 7/200 - Train Loss: 0.4907 - Test Loss: 0.4890
# Epoch 8/200 - Train Loss: 0.4885 - Test Loss: 0.4865
# Epoch 9/200 - Train Loss: 0.4861 - Test Loss: 0.4838
# Epoch 10/200 - Train Loss: 0.4834 - Test Loss: 0.4807
# Epoch 11/200 - Train Loss: 0.4803 - Test Loss: 0.4772
# Epoch 12/200 - Train Loss: 0.4768 - Test Loss: 0.4730
# Epoch 13/200 - Train Loss: 0.4726 - Test Loss: 0.4680
# Epoch 14/200 - Train Loss: 0.4675 - Test Loss: 0.4618
# Epoch 15/200 - Train Loss: 0.4612 - Test Loss: 0.4542
# Epoch 16/200 - Train Loss: 0.4534 - Test Loss: 0.4446
# Epoch 17/200 - Train Loss: 0.4435 - Test Loss: 0.4325
# Epoch 18/200 - Train Loss: 0.4311 - Test Loss: 0.4169
# Epoch 19/200 - Train Loss: 0.4153 - Test Loss: 0.3965
# Epoch 20/200 - Train Loss: 0.3947 - Test Loss: 0.3694
# Epoch 21/200 - Train Loss: 0.3674 - Test Loss: 0.3337
# Epoch 22/200 - Train Loss: 0.3315 - Test Loss: 0.2881
# Epoch 23/200 - Train Loss: 0.2858 - Test Loss: 0.2352
# Epoch 24/200 - Train Loss: 0.2328 - Test Loss: 0.1846
# Epoch 25/200 - Train Loss: 0.1823 - Test Loss: 0.1495
# Epoch 26/200 - Train Loss: 0.1474 - Test Loss: 0.1313
# Epoch 27/200 - Train Loss: 0.1293 - Test Loss: 0.1241
# Epoch 28/200 - Train Loss: 0.1225 - Test Loss: 0.1147
# Epoch 29/200 - Train Loss: 0.1142 - Test Loss: 0.1007
# Epoch 30/200 - Train Loss: 0.1012 - Test Loss: 0.0894
# Epoch 31/200 - Train Loss: 0.0906 - Test Loss: 0.0805
# Epoch 32/200 - Train Loss: 0.0819 - Test Loss: 0.0717
# Epoch 33/200 - Train Loss: 0.0732 - Test Loss: 0.0647
# Epoch 34/200 - Train Loss: 0.0663 - Test Loss: 0.0592
# Epoch 35/200 - Train Loss: 0.0608 - Test Loss: 0.0528
# Epoch 36/200 - Train Loss: 0.0541 - Test Loss: 0.0455
# Epoch 37/200 - Train Loss: 0.0464 - Test Loss: 0.0387
# Epoch 38/200 - Train Loss: 0.0393 - Test Loss: 0.0327
# Epoch 39/200 - Train Loss: 0.0330 - Test Loss: 0.0269
# Epoch 40/200 - Train Loss: 0.0271 - Test Loss: 0.0219
# Epoch 41/200 - Train Loss: 0.0220 - Test Loss: 0.0183
# Epoch 42/200 - Train Loss: 0.0184 - Test Loss: 0.0155
# Epoch 43/200 - Train Loss: 0.0155 - Test Loss: 0.0128
# Epoch 44/200 - Train Loss: 0.0128 - Test Loss: 0.0106
# Epoch 45/200 - Train Loss: 0.0107 - Test Loss: 0.0091
# Epoch 46/200 - Train Loss: 0.0092 - Test Loss: 0.0078
# Epoch 47/200 - Train Loss: 0.0080 - Test Loss: 0.0067
# Epoch 48/200 - Train Loss: 0.0069 - Test Loss: 0.0063
# Epoch 49/200 - Train Loss: 0.0064 - Test Loss: 0.0062
# Epoch 50/200 - Train Loss: 0.0063 - Test Loss: 0.0061
# Epoch 51/200 - Train Loss: 0.0062 - Test Loss: 0.0060
# Epoch 52/200 - Train Loss: 0.0060 - Test Loss: 0.0059
# Epoch 53/200 - Train Loss: 0.0059 - Test Loss: 0.0056
# Epoch 54/200 - Train Loss: 0.0056 - Test Loss: 0.0051
# Epoch 55/200 - Train Loss: 0.0052 - Test Loss: 0.0047
# Epoch 56/200 - Train Loss: 0.0047 - Test Loss: 0.0043
# Epoch 57/200 - Train Loss: 0.0043 - Test Loss: 0.0039
# Epoch 58/200 - Train Loss: 0.0039 - Test Loss: 0.0035
# Epoch 59/200 - Train Loss: 0.0036 - Test Loss: 0.0033
# Epoch 60/200 - Train Loss: 0.0034 - Test Loss: 0.0031
# Epoch 61/200 - Train Loss: 0.0031 - Test Loss: 0.0029
# Epoch 62/200 - Train Loss: 0.0029 - Test Loss: 0.0027
# Epoch 63/200 - Train Loss: 0.0027 - Test Loss: 0.0025
# Epoch 64/200 - Train Loss: 0.0025 - Test Loss: 0.0023
# Epoch 65/200 - Train Loss: 0.0022 - Test Loss: 0.0020
# Epoch 66/200 - Train Loss: 0.0020 - Test Loss: 0.0018
# Epoch 67/200 - Train Loss: 0.0018 - Test Loss: 0.0017
# Epoch 68/200 - Train Loss: 0.0017 - Test Loss: 0.0015
# Epoch 69/200 - Train Loss: 0.0015 - Test Loss: 0.0013
# Epoch 70/200 - Train Loss: 0.0013 - Test Loss: 0.0012
# Epoch 71/200 - Train Loss: 0.0012 - Test Loss: 0.0011
# Epoch 72/200 - Train Loss: 0.0011 - Test Loss: 0.0010
# Epoch 73/200 - Train Loss: 0.0010 - Test Loss: 0.0009
# Epoch 74/200 - Train Loss: 0.0009 - Test Loss: 0.0009
# Epoch 75/200 - Train Loss: 0.0009 - Test Loss: 0.0009
# Epoch 76/200 - Train Loss: 0.0009 - Test Loss: 0.0009
# Epoch 77/200 - Train Loss: 0.0009 - Test Loss: 0.0009
# Epoch 78/200 - Train Loss: 0.0009 - Test Loss: 0.0008
# Epoch 79/200 - Train Loss: 0.0008 - Test Loss: 0.0008
# Epoch 80/200 - Train Loss: 0.0008 - Test Loss: 0.0007
# Epoch 81/200 - Train Loss: 0.0008 - Test Loss: 0.0007
# Epoch 82/200 - Train Loss: 0.0007 - Test Loss: 0.0007
# Epoch 83/200 - Train Loss: 0.0007 - Test Loss: 0.0006
# Epoch 84/200 - Train Loss: 0.0006 - Test Loss: 0.0006
# Epoch 85/200 - Train Loss: 0.0006 - Test Loss: 0.0006
# Epoch 86/200 - Train Loss: 0.0006 - Test Loss: 0.0005
# Epoch 87/200 - Train Loss: 0.0005 - Test Loss: 0.0005
# Epoch 88/200 - Train Loss: 0.0005 - Test Loss: 0.0005
# Epoch 89/200 - Train Loss: 0.0005 - Test Loss: 0.0004
# Epoch 90/200 - Train Loss: 0.0004 - Test Loss: 0.0004
# Epoch 91/200 - Train Loss: 0.0004 - Test Loss: 0.0004
# Epoch 92/200 - Train Loss: 0.0004 - Test Loss: 0.0004
# Epoch 93/200 - Train Loss: 0.0004 - Test Loss: 0.0004
# Epoch 94/200 - Train Loss: 0.0004 - Test Loss: 0.0004
# Epoch 95/200 - Train Loss: 0.0004 - Test Loss: 0.0003
# Epoch 96/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 97/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 98/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 99/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 100/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 101/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 102/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 103/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 104/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 105/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 106/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 107/200 - Train Loss: 0.0003 - Test Loss: 0.0003
# Epoch 108/200 - Train Loss: 0.0003 - Test Loss: 0.0002
# Epoch 109/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 110/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 111/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 112/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 113/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 114/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 115/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 116/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 117/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 118/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 119/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 120/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 121/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 122/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 123/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 124/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 125/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 126/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 127/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 128/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 129/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 130/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 131/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 132/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 133/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 134/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 135/200 - Train Loss: 0.0002 - Test Loss: 0.0002
# Epoch 136/200 - Train Loss: 0.0002 - Test Loss: 0.0001
# Epoch 137/200 - Train Loss: 0.0002 - Test Loss: 0.0001
# Epoch 138/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 139/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 140/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 141/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 142/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 143/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 144/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 145/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 146/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 147/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 148/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 149/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 150/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 151/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 152/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 153/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 154/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 155/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 156/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 157/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 158/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 159/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 160/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 161/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 162/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 163/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 164/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 165/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 166/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 167/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 168/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 169/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 170/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 171/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 172/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 173/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 174/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 175/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 176/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 177/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 178/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 179/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 180/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 181/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 182/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 183/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 184/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 185/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 186/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 187/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 188/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 189/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 190/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 191/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 192/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 193/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 194/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 195/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 196/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 197/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 198/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 199/200 - Train Loss: 0.0001 - Test Loss: 0.0001
# Epoch 200/200 - Train Loss: 0.0001 - Test Loss: 0.0001

# %%
y_x = Y_test[:look_back].copy()
y_x.shape
y_x = torch.tensor(y_x, dtype=torch.float32).view(-1, look_back, 1)
y_x.shape
# Out:
# torch.Size([1, 20, 1])

# %%
# predY = lstm_long(testX.to(device)).cpu().detach().numpy()
predY = lstm_long(y_x.to(device)).cpu().detach().numpy()


plt.figure(figsize=(15, 4))
# plt.plot(X_train, Y_train, label="Train data")
# plt.plot(X_test, Y_test, label="Test data")
# plt.plot(X_test[look_back:-look_forward], predY[:, 0], "g-", label="Predicted data")
plt.plot(X_test[:3*look_forward], Y_test[:3* look_forward], "k-.", label="truth")
plt.plot(X_test[:look_back], Y_test[:look_back], "rx", label="Initial data")
plt.plot(X_test[look_back:look_back+look_forward], predY[0].flatten(), "g-", label="Predicted data")
plt.legend(loc="lower left")
plt.show()

plt.figure(figsize=(15, 4))
error = np.abs(Y_test[look_back:look_back+look_forward] - predY[0].flatten())
plt.plot(X_test[look_back:look_back+look_forward], error, "r-", label="Error")
plt.title("Total error: %.4f" % np.sum(error))
plt.plot()
# Out:
# []

# %%
import platform
print(platform.platform())
print(platform.processor())
print(torch.__version__)
# Out:
# Windows-10-10.0.22631-SP0
# Intel64 Family 6 Model 186 Stepping 2, GenuineIntel
# 2.3.1+cu121
