# %%
import cv2

# %%
# Attempt to open the default camera (index 0)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    
    # Check if frame is empty
    if frame is None or frame.size == 0:
        print("Empty frame received")
        continue

    print("Frame received")
    
    # Display the frame
    cv2.imshow('frame', frame)
    
    # Wait for 'q' key press for 30ms
    if cv2.waitKey(30) == ord('q'):
        break

# Release the camera and destroy all windows
cap.release()
cv2.destroyAllWindows()
print("Camera released and windows destroyed")
# Out:
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Frame received
# Camera released and windows destroyed

# %%
from ultralytics import YOLO
import cv2
import math

# Initialize webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)  # Set width
cap.set(4, 480)  # Set height

# Load YOLO model
model = YOLO("yolo-Weights/yolov8n.pt")  # Ensure the path is correct

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

while True:
    success, img = cap.read()
    if not success:
        print("Failed to grab frame")
        break

    print("Frame received")

    # Perform object detection
    # results = model(img)

    # # Iterate over detected objects
    # for result in results:
    #     boxes = result.boxes.cpu().numpy()  # Ensure the results are on the CPU and convert to numpy array

    #     for box in boxes:
    #         # Bounding box coordinates
    #         x1, y1, x2, y2 = map(int, box[:4])  # Convert to int values

    #         # Draw bounding box on the frame
    #         cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

    #         # Extract confidence score and class index
    #         confidence = round(float(box[4]), 2)
    #         cls = int(box[5])

    #         # Check if class index is within bounds
    #         if cls < len(classNames):
    #             class_name = classNames[cls]
    #             print(f"Detected {class_name} with confidence {confidence}")
    #         else:
    #             print(f"Class index {cls} out of bounds")

    #         # Put class name on the frame
    #         cv2.putText(img, f"{class_name} {confidence}", (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Display the frame
    print("Displaying frame")
    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
print("Resources released")
# Out:
# Failed to grab frame
# Resources released
